# %%
def sum_all(n):
    total = 0
    for num in range(1, n+1):
        total += num
    return total

# %%
sum_all(100)
# Out:
# 5050

# %%
def sum_all(n):
    return int(n *(n+1) / 2)

# %%
sum_all(100)
# Out:
# 5050
