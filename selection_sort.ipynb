# %%
import random
data_list = random.sample(range(100), 10)

# %%
def selection_sort(data_list):
    for stand in range(len(data_list) - 1):
        print(stand)
        lowest = stand
        for num in range(stand, len(data_list)):
            if data_list[lowest] > data_list[num]:
                lowest = num
        data_list[stand], data_list[lowest] = data_list[lowest], data_list[stand]
        print(data_list)
    return data_list

# %%
selection_sort(data_list)
# Out:
# 0
# [17, 91, 38, 89, 63, 50, 97, 31, 33, 29]
# 1
# [17, 29, 38, 89, 63, 50, 97, 31, 33, 91]
# 2
# [17, 29, 31, 89, 63, 50, 97, 38, 33, 91]
# 3
# [17, 29, 31, 33, 63, 50, 97, 38, 89, 91]
# 4
# [17, 29, 31, 33, 38, 50, 97, 63, 89, 91]
# 5
# [17, 29, 31, 33, 38, 50, 97, 63, 89, 91]
# 6
# [17, 29, 31, 33, 38, 50, 63, 97, 89, 91]
# 7
# [17, 29, 31, 33, 38, 50, 63, 89, 97, 91]
# 8
# [17, 29, 31, 33, 38, 50, 63, 89, 91, 97]
# [17, 29, 31, 33, 38, 50, 63, 89, 91, 97]
