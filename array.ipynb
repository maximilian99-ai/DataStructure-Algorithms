# %%
data = [[1, 2, 3,], [4, 5, 6], [7, 8, 9]]
print(data[0])
# Out:
# [1, 2, 3]

# %%
print(data[1][0])
print(data[1][1])
print(data[1][2])
# Out:
# 4
# 5
# 6

# %%
print(data[2][2], data[2][1], data[2][0])
# Out:
# 9 8 7
