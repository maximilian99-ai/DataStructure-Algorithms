# %%
def func(n):
  count = 0
  for num in range(1, n+1):
    count += num
  return count

func(10)
# Out:
# 55

# %%
def sum_all(n):
  total = 0
  for num in range(1, n+1):
    total += num
  return total

# %%
sum_all(100)
# Out:
# 5050

# %%
def sum_all(n):
  return int(n * (n+1) / 2)

# %%
sum_all(100)
# Out:
# 5050

# %%
def find_same_name(name_list):
  for index1, name in enumerate(name_list):
    for index2 in range(index1 + 1, len(name_list)):
      if (name == name_list[index2]):
        del name_list[index2]

  return name_list

# %%
names = ['Dave', 'David', 'Anthony', 'David', 'Dave']
find_same_name(names)
# Out:
# ['Dave', 'David', 'Anthony']
