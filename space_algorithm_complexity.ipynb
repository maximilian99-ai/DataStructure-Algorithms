# %%
def factorial(n):
    fac = 1
    for index in range(2, n+1):
        fac = fac * index
    return fac

# %%
factorial(3)
# Out:
# 6

# %%
def factorial(n):
    if n > 1:
        return n * factorial(n-1)
    else:
        return 1

# %%
factorial(3)
# Out:
# 6
